# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src import cleaning,visualize

# %%
subject_no = 1
n_ica_components = 10

subject_ica_object,subject_recording = cleaning.fit_ica(subject_no,n_components = n_ica_components)
# Out:
# C:\Users\20gun\anaconda3\envs\eeg\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)

# %%
subject_ica_object.plot_sources(subject_recording,show_scrollbars = False);
# Out:
# <MNEBrowseFigure size 1536x897.6 with 4 Axes>

# %%
exclude = [0,1]
subject_ica_object.plot_overlay(subject_recording,exclude);

# %%
chs_to_exclude = [0,1,3,9]

cleaned_subject_recording = cleaning.clean_recording(subject_recording,subject_ica_object,chs_to_exclude)

# %%
clean_ica_object = cleaning.get_sources_clean(cleaned_subject_recording,n_components = n_ica_components)

# %%
clean_ica_object.plot_sources(cleaned_subject_recording,show_scrollbars = False);
# Out:
# <MNEBrowseFigure size 1536x897.6 with 4 Axes>

# %%
cleaned_subject_recording.plot(show_scrollbars = False);
# Out:
# <MNEBrowseFigure size 1536x897.6 with 4 Axes>

# %%
event_ids = [7,8,9,10]
visualize.show_evoked(cleaned_subject_recording,event_ids,tmin = -0.5,tmax = 0.7)
